# %% [markdown]
# ### Import the required libraries

# %%
import os, sys
import matplotlib.pyplot as plt
import numpy as np 
import PIL 
import tensorflow as tf
from tensorflow import keras 
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from pathlib import Path
import random
import cv2
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Download the dataset

# %%
# Classes we have in our data set.
total_classes = os.listdir(r"C:\Users\DELL\Downloads\Dataset")
total_classes
# Out:
# ['Mild_Demented', 'Moderate_Demented', 'Non_Demented', 'Very_Mild_Demented']

# %%
# Total number of images per class.
images_path = Path(r"C:\Users\DELL\Downloads\Dataset")

for c in total_classes:
  print(f'* {c}', '=',len(os.listdir(os.path.join(images_path, c))), 'images')
# Out:
# * Mild_Demented = 896 images
# * Moderate_Demented = 64 images
# * Non_Demented = 3200 images
# * Very_Mild_Demented = 2240 images

# %% [markdown]
# We can see a class imbalance here !

# %%
# Let's display 1 image per class.

fig,ax = plt.subplots(1,4,figsize=(10,4))
ax = ax.flat
for i,c in enumerate(total_classes):
  img_total_class = list(Path(os.path.join(images_path, c)).glob("*.jpg"))
  img_selected = random.choice(img_total_class)
  img_BGR = cv2.imread(str(img_selected))
  img_RGB = cv2.cvtColor(img_BGR, cv2.COLOR_BGR2RGB)
  height,width,channel = img_RGB.shape
  ax[i].imshow(img_RGB)
  ax[i].set_title(f"{img_selected.parent.stem}\nheight:{height}\nwidth:{width}")
  ax[i].axis("off")

fig.tight_layout()
fig.show()

# %%
batch_size = 32
img_height = 180
img_width = 180

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
    images_path,
    validation_split=0.2,
    subset="training",
    seed=123,
    image_size = (img_height, img_width),
    batch_size=batch_size)
# Out:
# Found 6400 files belonging to 4 classes.
# Using 5120 files for training.

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
    images_path,
    validation_split=0.2,
    subset="validation",
    seed=123,
    image_size=(img_height, img_width),
    batch_size=batch_size)
# Out:
# Found 6400 files belonging to 4 classes.
# Using 1280 files for validation.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['Mild_Demented', 'Moderate_Demented', 'Non_Demented', 'Very_Mild_Demented']

# %% [markdown]
# ### Visualize the data

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(8):
        ax = plt.subplot(2, 4, i+1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")

# %%
for image_batch, labels_batch in train_ds:
    print(image_batch.shape)
    print(labels_batch.shape)
    break
# Out:
# (32, 180, 180, 3)
# (32,)

# %% [markdown]
# ### Configure the data for higher performance

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ### Standardizing the dataset

# %%
normalization_layer = layers.Rescaling(1./255)

# %%
normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_ds))
first_image = image_batch[0]

# Notice the pixel values are now in '[0,1]'

print(np.min(first_image), np.max(first_image))
# Out:
# 0.0 0.8505326

# %% [markdown]
# ### Create the Model

# %%
num_classes = len(class_names)

model = Sequential([
    layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
    layers.Conv2D(16, 3, padding="same", activation="relu"),
    layers.MaxPooling2D(),
    layers.Conv2D(32, 3, padding="same", activation="relu"),
    layers.MaxPooling2D(),
    layers.Conv2D(64, 3, padding="same", activation="relu"),
    layers.MaxPooling2D(),
    layers.Flatten(),
    layers.Dense(128, activation="relu"),
    layers.Dense(num_classes)
])

# %% [markdown]
# ### Compile the Model

# %%
model.compile(optimizer="adam",
             loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
             metrics=["accuracy"])

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ rescaling_1 (Rescaling)              │ (None, 180, 180, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d (Conv2D)                      │ (None, 180, 180, 16)        │             448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 90, 90, 16)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 90, 90, 32)          │           4,640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 45, 45, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 45, 45, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 22, 22, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 30976)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │       3,965,056 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 4)                   │             516 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 3,989,156 (15.22 MB)
#  Trainable params: 3,989,156 (15.22 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Train the Model

# %%
epochs = 10 

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=epochs)
# Out:
# Epoch 1/10
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 51s 278ms/step - accuracy: 0.5001 - loss: 1.0347 - val_accuracy: 0.6703 - val_loss: 0.7579
# Epoch 2/10
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 41s 259ms/step - accuracy: 0.6831 - loss: 0.7288 - val_accuracy: 0.7852 - val_loss: 0.4929
# Epoch 3/10
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 40s 252ms/step - accuracy: 0.8632 - loss: 0.3634 - val_accuracy: 0.7922 - val_loss: 0.4639
# Epoch 4/10
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 37s 230ms/step - accuracy: 0.9481 - loss: 0.1489 - val_accuracy: 0.9062 - val_loss: 0.2315
# Epoch 5/10
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 39s 242ms/step - accuracy: 0.9695 - loss: 0.0834 - val_accuracy: 0.9547 - val_loss: 0.1201
# Epoch 6/10
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 40s 249ms/step - accuracy: 0.9959 - loss: 0.0201 - val_accuracy: 0.9703 - val_loss: 0.0883
# Epoch 7/10
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 39s 247ms/step - accuracy: 0.9988 - loss: 0.0055 - val_accuracy: 0.9883 - val_loss: 0.0415
# Epoch 8/10
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 40s 248ms/step - accuracy: 1.0000 - loss: 7.2879e-04 - val_accuracy: 0.9875 - val_loss: 0.0376
# Epoch 9/10
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 36s 223ms/step - accuracy: 1.0000 - loss: 4.0389e-04 - val_accuracy: 0.9883 - val_loss: 0.0371
# Epoch 10/10
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 33s 204ms/step - accuracy: 1.0000 - loss: 2.7925e-04 - val_accuracy: 0.9883 - val_loss: 0.0372

# %% [markdown]
# ### Visualizing the results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8,8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title("Training and Validation Accuracy")

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# ### Data Augmentation

# %%
data_augmentation = keras.Sequential(
[
    layers.RandomFlip("horizontal",
                     input_shape=(img_height,
                                 img_width,
                                  3)),
    
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1)
])

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
    for i in range(8):
        augmented_images = data_augmentation(images)
        ax = plt.subplot(4,2, i+1)
        plt.imshow(augmented_images[0].numpy().astype("uint8"))
        plt.axis("off")

# %% [markdown]
# ### Adding Dropout Layer

# %%
model = Sequential([
    layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
    layers.Conv2D(16, 3, padding="same", activation="relu"),
    layers.MaxPooling2D(),
    layers.Conv2D(32, 3, padding="same", activation="relu"),
    layers.MaxPooling2D(),
    layers.Conv2D(64, 3, padding="same", activation="relu"),
    layers.MaxPooling2D(),
    layers.Dropout(0.2),
    layers.Flatten(),
    layers.Dense(128, activation="relu"),
    layers.Dense
# Epoch 27/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 40s 250ms/step - accuracy: 1.0000 - loss: 7.4574e-06 - val_accuracy: 0.9906 - val_loss: 0.0394
# Epoch 28/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 41s 253ms/step - accuracy: 1.0000 - loss: 6.2051e-06 - val_accuracy: 0.9906 - val_loss: 0.0401
# Epoch 29/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 40s 251ms/step - accuracy: 1.0000 - loss: 5.5884e-06 - val_accuracy: 0.9898 - val_loss: 0.0404
# Epoch 30/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 40s 250ms/step - accuracy: 1.0000 - loss: 5.1685e-06 - val_accuracy: 0.9898 - val_loss: 0.0409
# Epoch 31/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 40s 250ms/step - accuracy: 1.0000 - loss: 4.6069e-06 - val_accuracy: 0.9898 - val_loss: 0.0412
# Epoch 32/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 40s 252ms/step - accuracy: 1.0000 - loss: 4.0346e-06 - val_accuracy: 0.9898 - val_loss: 0.0409
# Epoch 33/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 40s 251ms/step - accuracy: 1.0000 - loss: 4.2146e-06 - val_accuracy: 0.9898 - val_loss: 0.0413
# Epoch 34/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 40s 250ms/step - accuracy: 1.0000 - loss: 3.8900e-06 - val_accuracy: 0.9898 - val_loss: 0.0413
# Epoch 35/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 40s 251ms/step - accuracy: 1.0000 - loss: 3.2479e-06 - val_accuracy: 0.9898 - val_loss: 0.0422
# Epoch 36/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 43s 268ms/step - accuracy: 1.0000 - loss: 2.8519e-06 - val_accuracy: 0.9906 - val_loss: 0.0417
# Epoch 37/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 43s 270ms/step - accuracy: 1.0000 - loss: 2.5910e-06 - val_accuracy: 0.9898 - val_loss: 0.0421
# Epoch 38/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 43s 270ms/step - accuracy: 1.0000 - loss: 2.6316e-06 - val_accuracy: 0.9898 - val_loss: 0.0429
# Epoch 39/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 34s 215ms/step - accuracy: 1.0000 - loss: 2.2650e-06 - val_accuracy: 0.9898 - val_loss: 0.0425
# Epoch 40/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 30s 185ms/step - accuracy: 1.0000 - loss: 1.9664e-06 - val_accuracy: 0.9898 - val_loss: 0.0435
# Epoch 41/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 31s 195ms/step - accuracy: 1.0000 - loss: 1.7401e-06 - val_accuracy: 0.9898 - val_loss: 0.0442
# Epoch 42/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 31s 193ms/step - accuracy: 1.0000 - loss: 1.5989e-06 - val_accuracy: 0.9898 - val_loss: 0.0444
# Epoch 43/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 32s 197ms/step - accuracy: 1.0000 - loss: 1.4733e-06 - val_accuracy: 0.9898 - val_loss: 0.0429
# Epoch 44/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 31s 193ms/step - accuracy: 1.0000 - loss: 1.2906e-06 - val_accuracy: 0.9898 - val_loss: 0.0443
# Epoch 45/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 32s 203ms/step - accuracy: 1.0000 - loss: 1.0892e-06 - val_accuracy: 0.9898 - val_loss: 0.0439
# Epoch 46/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 36s 223ms/step - accuracy: 1.0000 - loss: 9.7904e-07 - val_accuracy: 0.9898 - val_loss: 0.0437
# Epoch 47/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 43s 271ms/step - accuracy: 1.0000 - loss: 9.4187e-07 - val_accuracy: 0.9898 - val_loss: 0.0445
# Epoch 48/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 43s 266ms/step - accuracy: 1.0000 - loss: 7.8957e-07 - val_accuracy: 0.9898 - val_loss: 0.0443
# Epoch 49/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 43s 266ms/step - accuracy: 1.0000 - loss: 6.7357e-07 - val_accuracy: 0.9898 - val_loss: 0.0453
# Epoch 50/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 42s 266ms/step - accuracy: 1.0000 - loss: 6.7042e-07 - val_accuracy: 0.9914 - val_loss: 0.0449

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8,8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title("Training and Validation Accuracy")

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# ### Save the Model

# %%
# Save the Keras model as an HDF5 file
model.save("alzeihmer_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
